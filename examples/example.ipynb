# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append('../weeds_standalone')
from weeds_py import modsource
# %matplotlib inline

# %%
component = modsource.readmdl('cch.mdl')
freq,tb,tb_species,tau_tot,f_nu = modsource.modsource(component,261.98e3,262.1e3,theta_tel=0.5,extra_result=True)

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(121)
plt.plot(freq,tb)
plt.xlabel('Freq (MHz)')
plt.ylabel('T_b (K)')

ax = fig.add_subplot(122)
plt.plot(freq,f_nu)
plt.xlabel('Freq (MHz)')
plt.ylabel('Intensity (Jy)')
# Out:
#  5 025501 CCH, v=0 lines found in the frequency range
# partition function found
